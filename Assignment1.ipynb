# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38704853-c91a-4573-b749-95353020502b" name="files[]" multiple disabled />
#      <output id="result-38704853-c91a-4573-b749-95353020502b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a9ae23a8-bb57-44ac-ad11-92d7046706a9" name="files[]" multiple disabled />
#      <output id="result-a9ae23a8-bb57-44ac-ad11-92d7046706a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df = pd.read_csv('carpet.csv')

# %%
df1= pd.read_csv('hardwood.csv')

# %% [markdown]
# Question 1. Extract statistical information (e.g. number of observations, dimension of the data, mean of each feature, etc.) from these datasets. Also present visual representations (e.g. histogram, scatter plot, etc.) of the data. Is the dataset imbalanced, inaccurate or incomplete? Is it a trivial data or possibly a big data? Does it have scalability problem? Are they high dimensional? You need to write programs to read the data and do this.

# %%
#Checking dimension(features, observations)
df.shape
# Out:
# (1023, 64)

# %%
#Checking dimension(features, observations)
df1.shape
# Out:
# (1023, 64)

# %% [markdown]
# Dataset is quite imbalanced as the number of features is not appropriate to the number of observations.

# %%
#2 dimensions. The number of features is more than observations. Therefore, I consider it as high dimensional dataset.
df.ndim
# Out:
# 2

# %%
#2 dimensions. The number of features is more than observations. Therefore, I consider it as high dimensional dataset.
df1.ndim
# Out:
# 2

# %%
#dataset is complete
missing_data = df.isnull().sum()
missing_data.head()
# Out:
# 170.39    0
# 167.28    0
# 143.44    0
# 124.67    0
# 139.01    0
# dtype: int64

# %%
#dataset is complete
missing_data1 = df1.isnull().sum()
missing_data1.head()
# Out:
# 93.593    0
# 89.581    0
# 86.892    0
# 89.289    0
# 87.814    0
# dtype: int64

# %%
df.describe()
# Out:
#             170.39       167.28  ...       137.13       134.44
# count  1023.000000  1023.000000  ...  1023.000000  1023.000000
# mean    151.832293   151.265661  ...   152.035432   152.226859
# std      22.674795    22.048563  ...    22.590079    22.565857
# min      85.590000    81.564000  ...    84.649000    79.716000
# 25%     135.960000   135.895000  ...   136.395000   136.265000
# 50%     152.950000   151.250000  ...   153.330000   152.860000
# 75%     167.620000   165.760000  ...   168.265000   168.230000
# max     210.650000   210.200000  ...   203.640000   209.640000
#
# [8 rows x 64 columns]

# %% [markdown]
# According to the properties (mean, meadian, min, max, etc.) it should be claimed statistical results and range are similar.

# %%
df1.describe()
# Out:
#             93.593       89.581  ...       67.564       64.938
# count  1023.000000  1023.000000  ...  1023.000000  1023.000000
# mean     99.293614    99.441943  ...    98.838441    98.952951
# std      17.928921    18.013425  ...    18.476084    18.362967
# min      47.124000    47.262000  ...    50.691000    53.071000
# 25%      87.320500    86.838000  ...    85.382500    85.216000
# 50%     100.130000    99.884000  ...   100.480000   100.920000
# 75%     110.735000   111.220000  ...   111.485000   111.505000
# max     139.610000   139.600000  ...   140.020000   138.060000
#
# [8 rows x 64 columns]

# %% [markdown]
# According to the properties (mean, meadian, min, max, etc.) it should be claimed statistical results and range are similar.

# %%
#Creating name for each column. So it should be easier to differentiate and present visually.
df.columns = ["Carpet num"+ str(x) for x in range (len(df.columns))]
print(df.columns)
# Out:
# Index(['Carpet num0', 'Carpet num1', 'Carpet num2', 'Carpet num3',
#        'Carpet num4', 'Carpet num5', 'Carpet num6', 'Carpet num7',
#        'Carpet num8', 'Carpet num9', 'Carpet num10', 'Carpet num11',
#        'Carpet num12', 'Carpet num13', 'Carpet num14', 'Carpet num15',
#        'Carpet num16', 'Carpet num17', 'Carpet num18', 'Carpet num19',
#        'Carpet num20', 'Carpet num21', 'Carpet num22', 'Carpet num23',
#        'Carpet num24', 'Carpet num25', 'Carpet num26', 'Carpet num27',
#        'Carpet num28', 'Carpet num29', 'Carpet num30', 'Carpet num31',
#        'Carpet num32', 'Carpet num33', 'Carpet num34', 'Carpet num35',
#        'Carpet num36', 'Carpet num37', 'Carpet num38', 'Carpet num39',
#        'Carpet num40', 'Carpet num41', 'Carpet num42', 'Carpet num43',
#        'Carpet num44', 'Carpet num45', 'Carpet num46', 'Carpet num47',
#        'Carpet num48', 'Carpet num49', 'Carpet num50', 'Carpet num51',
# ...

# %%
df.head()
# Out:
#    Carpet num0  Carpet num1  ...  Carpet num62  Carpet num63
# 0       169.75       190.96  ...        166.86        137.69
# 1       153.69       153.68  ...        163.24        165.17
# 2       131.69       151.56  ...        177.35        174.61
# 3       162.85       158.88  ...        152.12        146.58
# 4       132.05       149.12  ...        142.06        154.87
#
# [5 rows x 64 columns]

# %%
df.tail()
# Out:
#       Carpet num0  Carpet num1  ...  Carpet num62  Carpet num63
# 1018       122.97       133.20  ...        129.62        161.66
# 1019       145.73       156.59  ...        140.44        143.72
# 1020       175.99       141.08  ...        137.95        134.96
# 1021       149.07       162.87  ...        105.21        104.68
# 1022       140.06       160.04  ...        143.07        152.65
#
# [5 rows x 64 columns]

# %%
#Creating name for each column. So it should be easier to differentiate and present visually.
df1.columns= ["Wood num"+ str(x) for x in range(len(df.columns))]
print(df1.columns)
# Out:
# Index(['Wood num0', 'Wood num1', 'Wood num2', 'Wood num3', 'Wood num4',
#        'Wood num5', 'Wood num6', 'Wood num7', 'Wood num8', 'Wood num9',
#        'Wood num10', 'Wood num11', 'Wood num12', 'Wood num13', 'Wood num14',
#        'Wood num15', 'Wood num16', 'Wood num17', 'Wood num18', 'Wood num19',
#        'Wood num20', 'Wood num21', 'Wood num22', 'Wood num23', 'Wood num24',
#        'Wood num25', 'Wood num26', 'Wood num27', 'Wood num28', 'Wood num29',
#        'Wood num30', 'Wood num31', 'Wood num32', 'Wood num33', 'Wood num34',
#        'Wood num35', 'Wood num36', 'Wood num37', 'Wood num38', 'Wood num39',
#        'Wood num40', 'Wood num41', 'Wood num42', 'Wood num43', 'Wood num44',
#        'Wood num45', 'Wood num46', 'Wood num47', 'Wood num48', 'Wood num49',
#        'Wood num50', 'Wood num51', 'Wood num52', 'Wood num53', 'Wood num54',
#        'Wood num55', 'Wood num56', 'Wood num57', 'Wood num58', 'Wood num59',
# ...

# %%
df1.head()
# Out:
#    Wood num0  Wood num1  Wood num2  ...  Wood num61  Wood num62  Wood num63
# 0     62.800     68.942     70.733  ...      91.933      86.628      86.684
# 1     91.456     95.562     95.546  ...      90.028      86.025      90.142
# 2     88.069     85.126     87.511  ...      85.426      89.038      89.705
# 3     91.156     89.904     88.336  ...      94.085      92.362      95.685
# 4     93.844     94.296     94.050  ...      81.970      82.800      83.532
#
# [5 rows x 64 columns]

# %%
df1.tail()
# Out:
#       Wood num0  Wood num1  Wood num2  ...  Wood num61  Wood num62  Wood num63
# 1018     98.263    100.060     98.223  ...      74.998      76.695      78.166
# 1019     75.507     73.811     73.184  ...      61.225      58.836      61.005
# 1020     97.784    101.720     99.211  ...     113.940     113.270     120.430
# 1021    119.330    118.820    119.030  ...     109.400     108.970     109.590
# 1022    109.510    108.060    106.520  ...     113.660     107.080     103.280
#
# [5 rows x 64 columns]

# %%
plt.hist(df['Carpet num7'], bins=30)
plt.show()

# %%
plt.hist(df['Carpet num30'], bins=30)
plt.show()

# %% [markdown]
# The features such as the Carpet num7 and the Carpet num30 have the same units and scales.

# %%
Carpet7 = [df['Carpet num7']]
Carpet30 = [df['Carpet num30']]

plt.hist(Carpet7, alpha=0.5, label='Carpet7', bins=30)
plt.hist(Carpet30, alpha=0.5, label='Carpet30', bins=30)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# This histogram proves the previous claim and enforces the idea that there is no need for extra action such as normalization or standardization.

# %%
plt.hist(df1['Wood num7'], bins=30)
plt.show()

# %%
plt.hist(df1['Wood num30'], bins=30)
plt.show()

# %% [markdown]
# The features such as the Wood num7 and the Wood num30 have the same units and scales.

# %%
Wood7 = [df1['Wood num7']]
Wood30 = [df1['Wood num30']]

plt.hist(Wood7, alpha=0.5, label='Wood7', bins=30)
plt.hist(Wood30, alpha=0.5, label='Wood30', bins=30)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# This histogram also proves the previous claim and enforces the idea that there is no need for extra action such as normalization or standardization.

# %%
#Creating boxplot. Outlier detection
df.boxplot(column = ['Carpet num1', 'Carpet num2', 'Carpet num3', 'Carpet num4', 'Carpet num5'])

# %% [markdown]
# We can observe some outliers in the boxplots.

# %%
#Creating boxplot. Outlier detection
df1.boxplot(column = ['Wood num1', 'Wood num2', 'Wood num3', 'Wood num4', 'Wood num5'])

# %% [markdown]
# We can observe some outliers in the boxplots.

# %% [markdown]
# Question 3. Merge carpet.csv and hardwood.csv and create a new csv file called carwood.csv in which insert a new column with label 0 for carpet observations and label 1 for hardwood observations. Now shuffle the observations randomly and create a new file called randcarwood.csv. Then divide this file into 80:20 and name the files with Trainrandcarwood80.csv and Testrandcarwood20.csv respectively. You must write a program to do these processes using a programming language of your choice. The use of a new language R or Python is preferred; however, it is your choice. Include first and last three observations of each file (instead of all data, too long) in the text so that we know what the data samples look like in the files. Include code/commands and results of showing how many records in each file.

# %%
#Merging 2 dataframes
files =[df, df1]
carwood = pd.concat(files)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#Inserting new columns with label 0 and label 1 respectively
carwood.loc[carwood[carwood.index <= 1022].index,'label']="0"
carwood.loc[carwood[carwood.index > 1022].index,'label']="1"

# %%
carwood.head()
# Out:
#    Carpet num0  Carpet num1  Carpet num10  ...  Wood num8  Wood num9  label
# 0       169.75       190.96        167.36  ...        NaN        NaN      0
# 1       153.69       153.68        160.39  ...        NaN        NaN      0
# 2       131.69       151.56        148.53  ...        NaN        NaN      0
# 3       162.85       158.88        138.04  ...        NaN        NaN      0
# 4       132.05       149.12        138.86  ...        NaN        NaN      0
#
# [5 rows x 129 columns]

# %%
carwood.tail()
# Out:
#       Carpet num0  Carpet num1  Carpet num10  ...  Wood num8  Wood num9  label
# 1018          NaN          NaN           NaN  ...     97.878    101.450      0
# 1019          NaN          NaN           NaN  ...     74.042     75.384      0
# 1020          NaN          NaN           NaN  ...    113.630    109.990      0
# 1021          NaN          NaN           NaN  ...    116.590    118.400      0
# 1022          NaN          NaN           NaN  ...    112.620    107.640      0
#
# [5 rows x 129 columns]

# %%
#shuffling the observations randomly 
from sklearn.utils import shuffle
randcarwood = shuffle(carwood)

# %%
randcarwood.head()
# Out:
#      Carpet num0  Carpet num1  Carpet num10  ...  Wood num8  Wood num9  label
# 532       152.57       118.38        144.26  ...        NaN        NaN      0
# 915       184.95       164.98        150.62  ...        NaN        NaN      0
# 479          NaN          NaN           NaN  ...     71.163     77.026      0
# 280          NaN          NaN           NaN  ...     90.046     91.147      0
# 12        153.41       173.65        147.23  ...        NaN        NaN      0
#
# [5 rows x 129 columns]

# %%
randcarwood = pd.DataFrame(np.random.randn(1023, 2))
msk = np.random.rand(len(df)) < 0.8
Trainrandcarwood80 = randcarwood[msk]
Testrandcarwood20 = randcarwood[~msk]

# %%
len(Trainrandcarwood80)
# Out:
# 814

# %%
len(Testrandcarwood20)
# Out:
# 209

# %%
#Changing dataframes to csv files

randcarwood.to_csv(r'randcarwood.csv', index=False)
Trainrandcarwood80.to_csv(r'Trainrandcarwood80.csv', index=False)
Testrandcarwood20.to_csv(r'Testrandcarwood20.csv', index=False)
